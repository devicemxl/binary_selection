# %% [markdown]
# <center>
#
# # Should This Loan be Approved or Denied?
#
# ## *Book Zero: Dataset Exploration*
#
# </center>

# %% [markdown]
# ### ABSTRACT
#
# For this case-study assignment, students assume the role of loan officer at a bank and are asked to approve or deny a loan by assessing its risk of default using

# %% [markdown]
# ---
#
# ## I. Enviroment

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from warnings import filterwarnings
#from IPython.display import display, HTML
from MungingOps import GetDataDictionary

# %%
filterwarnings('ignore')

# %% [markdown]
# ### Styling

# %%
#
pd.options.display.float_format = '{:.5f}'.format
#--
sns.set_style("whitegrid")

# %% [markdown]
# ---
#
# ## II. Load and understand the data

# %% [markdown]
# ### 1. Load Data

# %% [markdown]
# The arff files contains in the header a file descriptor, then we can obtain valuable information about the dataset

# %%
#Read csv file
#RawDf = pd.read_csv('../input/should-this-loan-be-approved-or-denied/SBAnational.csv', header ='infer')
raw_df = pd.read_csv('./raw/SBAnational.csv', header ='infer')

# %% [markdown]
# ### 2. Dataset Structure

# %%
raw_df.shape
# Out:
# (899164, 27)

# %%
raw_df.head()
# Out:
#    LoanNr_ChkDgt                           Name          City State    Zip  \
# 0     1000014003                 ABC HOBBYCRAFT    EVANSVILLE    IN  47711
# 1     1000024006    LANDMARK BAR & GRILLE (THE)     NEW PARIS    IN  46526
# 2     1000034009          WHITLOCK DDS, TODD M.   BLOOMINGTON    IN  47401
# 3     1000044001  BIG BUCKS PAWN & JEWELRY, LLC  BROKEN ARROW    OK  74012
# 4     1000054004    ANASTASIA CONFECTIONS, INC.       ORLANDO    FL  32801
#
#                             Bank BankState   NAICS ApprovalDate ApprovalFY  \
# 0               FIFTH THIRD BANK        OH  451120    28-Feb-97       1997
# 1                1ST SOURCE BANK        IN  722410    28-Feb-97       1997
# 2        GRANT COUNTY STATE BANK        IN  621210    28-Feb-97       1997
# 3  1ST NATL BK & TR CO OF BROKEN        OK       0    28-Feb-97       1997
# 4        FLORIDA BUS. DEVEL CORP        FL       0    28-Feb-97       1997
#
#    ...  RevLineCr  LowDoc  ChgOffDate  DisbursementDate  DisbursementGross  \
# 0  ...          N       Y         NaN         28-Feb-99        $60,000.00
# 1  ...          N       Y         NaN         31-May-97        $40,000.00
# 2  ...          N       N         NaN         31-Dec-97       $287,000.00
# 3  ...          N       Y         NaN         30-Jun-97        $35,000.00
# 4  ...          N       N         NaN         14-May-97       $229,000.00
#
#    BalanceGross  MIS_Status ChgOffPrinGr        GrAppv      SBA_Appv
# 0        $0.00        P I F       $0.00    $60,000.00    $48,000.00
# 1        $0.00        P I F       $0.00    $40,000.00    $32,000.00
# 2        $0.00        P I F       $0.00   $287,000.00   $215,250.00
# 3        $0.00        P I F       $0.00    $35,000.00    $28,000.00
# 4        $0.00        P I F       $0.00   $229,000.00   $229,000.00
#
# [5 rows x 27 columns]

# %%
description = raw_df.describe(include='all').T
description.to_excel('./original_metadata.xlsx')# To put in the report
display(description)
# Out:
#                          count   unique                         top  \
# LoanNr_ChkDgt     899164.00000      NaN                         NaN
# Name                    899150   779583                      SUBWAY
# City                    899134    32581                 LOS ANGELES
# State                   899150       51                          CA
# Zip               899164.00000      NaN                         NaN
# Bank                    897605     5802  BANK OF AMERICA NATL ASSOC
# BankState               897598       56                          CA
# NAICS             899164.00000      NaN                         NaN
# ApprovalDate            899164     9859                    7-Jul-93
# ApprovalFY        899164.00000 75.00000                  2006.00000
# Term              899164.00000      NaN                         NaN
# NoEmp             899164.00000      NaN                         NaN
# NewExist          899028.00000      NaN                         NaN
# CreateJob         899164.00000      NaN                         NaN
# RetainedJob       899164.00000      NaN                         NaN
# FranchiseCode     899164.00000      NaN                         NaN
# UrbanRural        899164.00000      NaN                         NaN
# RevLineCr               894636       18                           N
# LowDoc                  896582        8                           N
# ChgOffDate              162699     6448                   13-Mar-10
# DisbursementDate        896796     8472                   31-Jul-95
# DisbursementGross       899164   118859                 $50,000.00
# BalanceGross            899164       15                      $0.00
# MIS_Status              897167        2                       P I F
# ChgOffPrinGr            899164    83165                      $0.00
# GrAppv                  899164    22128                 $50,000.00
# SBA_Appv                899164    38326                 $25,000.00
#
#                          freq             mean              std  \
# LoanNr_ChkDgt             NaN 4772612310.59431 2538175037.45304
# Name                     1269              NaN              NaN
# City                    11558              NaN              NaN
# State                  130619              NaN              NaN
# Zip                       NaN      53804.39124      31184.15915
# Bank                    86853              NaN              NaN
# BankState              118116              NaN              NaN
# NAICS                     NaN     398660.95015     263318.31276
# ApprovalDate             1131              NaN              NaN
# ApprovalFY        76039.00000              NaN              NaN
# Term                      NaN        110.77308         78.85731
# NoEmp                     NaN         11.41135         74.10820
# NewExist                  NaN          1.28040          0.45175
# CreateJob                 NaN          8.43038        236.68817
# RetainedJob               NaN         10.79726        237.12060
# FranchiseCode             NaN       2753.72593      12758.01914
# UrbanRural                NaN          0.75775          0.64644
# RevLineCr              420288              NaN              NaN
# LowDoc                 782822              NaN              NaN
# ChgOffDate                734              NaN              NaN
# DisbursementDate        10371              NaN              NaN
# DisbursementGross       43787              NaN              NaN
# BalanceGross           899150              NaN              NaN
# MIS_Status             739609              NaN              NaN
# ChgOffPrinGr           737152              NaN              NaN
# GrAppv                  69394              NaN              NaN
# SBA_Appv                49579              NaN              NaN
#
#                                min              25%              50%  \
# LoanNr_ChkDgt     1000014003.00000 2589757508.50000 4361439006.00000
# Name                           NaN              NaN              NaN
# City                           NaN              NaN              NaN
# State                          NaN              NaN              NaN
# Zip                        0.00000      27587.00000      55410.00000
# Bank                           NaN              NaN              NaN
# BankState                      NaN              NaN              NaN
# NAICS                      0.00000     235210.00000     445310.00000
# ApprovalDate                   NaN              NaN              NaN
# ApprovalFY                     NaN              NaN              NaN
# Term                       0.00000         60.00000         84.00000
# NoEmp                      0.00000          2.00000          4.00000
# NewExist                   0.00000          1.00000          1.00000
# CreateJob                  0.00000          0.00000          0.00000
# RetainedJob                0.00000          0.00000          1.00000
# FranchiseCode              0.00000          1.00000          1.00000
# UrbanRural                 0.00000          0.00000          1.00000
# RevLineCr                      NaN              NaN              NaN
# LowDoc                         NaN              NaN              NaN
# ChgOffDate                     NaN              NaN              NaN
# DisbursementDate               NaN              NaN              NaN
# DisbursementGross              NaN              NaN              NaN
# BalanceGross                   NaN              NaN              NaN
# MIS_Status                     NaN              NaN              NaN
# ChgOffPrinGr                   NaN              NaN              NaN
# GrAppv                         NaN              NaN              NaN
# SBA_Appv                       NaN              NaN              NaN
#
#                                75%              max
# LoanNr_ChkDgt     6904626504.75000 9996003010.00000
# Name                           NaN              NaN
# City                           NaN              NaN
# State                          NaN              NaN
# Zip                    83704.00000      99999.00000
# Bank                           NaN              NaN
# BankState                      NaN              NaN
# NAICS                 561730.00000     928120.00000
# ApprovalDate                   NaN              NaN
# ApprovalFY                     NaN              NaN
# Term                     120.00000        569.00000
# NoEmp                     10.00000       9999.00000
# NewExist                   2.00000          2.00000
# CreateJob                  1.00000       8800.00000
# RetainedJob                4.00000       9500.00000
# FranchiseCode              1.00000      99999.00000
# UrbanRural                 1.00000          2.00000
# RevLineCr                      NaN              NaN
# LowDoc                         NaN              NaN
# ChgOffDate                     NaN              NaN
# DisbursementDate               NaN              NaN
# DisbursementGross              NaN              NaN
# BalanceGross                   NaN              NaN
# MIS_Status                     NaN              NaN
# ChgOffPrinGr                   NaN              NaN
# GrAppv                         NaN              NaN
# SBA_Appv                       NaN              NaN

# %% [markdown]
# The first step is change the column case and subtitute acronymes to improve readability

# %%
new_columns =   {'id':                      'Identifier - Primary key'
                 ,'borrower_name':          'Borrower Name'
                 ,'borrower_city':          'Borrower city'
                 ,'borrower_state':         'Borrower state'
                 ,'borrower_zip':           'Borrower zip code'
                 ,'bank_name':              'Bank name'
                 ,'bank_state':             'Bank state'
                 ,'naic':                   'North American Industry classification'
                 ,'approval_date':          'Date SBA commitment issued'
                 ,'approval_fiscal_year':   'Fiscal year of commitment'
                 ,'spected_term':           'Loan termination months'
                 ,'employees':              'Number of business employees'
                 ,'business_type':          'Business Type'
                 ,'created_jobs':           'Number of jobs created'
                 ,'retained_jobs':          'Number of jobs retained'
                 ,'franchise':              'Franchise code'
                 ,'urban':                  'Urban or Rural'
                 ,'revolving_credit':       'Revolving line of credit'
                 ,'low_doc_loan':           'LowDoc Loan Program' 
                 ,'default_date':           'loan default´s declaration date'
                 ,'disbursement_date':      'the date upon which the Loan proceeds'
                 ,'amount_disbursed':       'Amount disbursed'
                 ,'gross_amount_outstanding':'the total of all remaining payments due under a Contract plus any other amount due thereunder'
                 ,'loan_status':            'Loan Status'
                 # 'charged_off_amount' == > 'ghargedoff_amount'
                 ,'charged_off_amount':     'debt that a company believes it will no longer collect as the borrower has become delinquent on payments'
                 ,'gross_amount_approved':  'gross disbursements represent the amount of checks issued, cash, or other payments made, less refunds received'
                 ,'guaranteed_sba':         'SBA´s guaranteed amount'
}

# %% [markdown]
# Check for errors in list len

# %%
len(raw_df.columns)-len(new_columns.keys())
# Out:
# 0

# %%
variables=raw_df
variables.columns = new_columns.keys()
display(variables)
# Out:
#                 id                   borrower_name    borrower_city  \
# 0       1000014003                  ABC HOBBYCRAFT       EVANSVILLE
# 1       1000024006     LANDMARK BAR & GRILLE (THE)        NEW PARIS
# 2       1000034009           WHITLOCK DDS, TODD M.      BLOOMINGTON
# 3       1000044001   BIG BUCKS PAWN & JEWELRY, LLC     BROKEN ARROW
# 4       1000054004     ANASTASIA CONFECTIONS, INC.          ORLANDO
# ...            ...                             ...              ...
# 899159  9995573004                    FABRIC FARMS  UPPER ARLINGTON
# 899160  9995603000                    FABRIC FARMS         COLUMBUS
# 899161  9995613003    RADCO MANUFACTURING CO.,INC.      SANTA MARIA
# 899162  9995973006           MARUTAMA HAWAII, INC.         HONOLULU
# 899163  9996003010  PACIFIC TRADEWINDS FAN & LIGHT           KAILUA
#
#        borrower_state  borrower_zip                       bank_name  \
# 0                  IN         47711                FIFTH THIRD BANK
# 1                  IN         46526                 1ST SOURCE BANK
# 2                  IN         47401         GRANT COUNTY STATE BANK
# 3                  OK         74012   1ST NATL BK & TR CO OF BROKEN
# 4                  FL         32801         FLORIDA BUS. DEVEL CORP
# ...               ...           ...                             ...
# 899159             OH         43221  JPMORGAN CHASE BANK NATL ASSOC
# 899160             OH         43221  JPMORGAN CHASE BANK NATL ASSOC
# 899161             CA         93455  RABOBANK, NATIONAL ASSOCIATION
# 899162             HI         96830                  BANK OF HAWAII
# 899163             HI         96734            CENTRAL PACIFIC BANK
#
#        bank_state    naic approval_date approval_fiscal_year  ...  \
# 0              OH  451120     28-Feb-97                 1997  ...
# 1              IN  722410     28-Feb-97                 1997  ...
# 2              IN  621210     28-Feb-97                 1997  ...
# 3              OK       0     28-Feb-97                 1997  ...
# 4              FL       0     28-Feb-97                 1997  ...
# ...           ...     ...           ...                  ...  ...
# 899159         IL  451120     27-Feb-97                 1997  ...
# 899160         IL  451130     27-Feb-97                 1997  ...
# 899161         CA  332321     27-Feb-97                 1997  ...
# 899162         HI       0     27-Feb-97                 1997  ...
# 899163         HI       0     27-Feb-97                 1997  ...
#
#         revolving_credit  low_doc_loan  default_date  disbursement_date  \
# 0                      N             Y           NaN          28-Feb-99
# 1                      N             Y           NaN          31-May-97
# 2                      N             N           NaN          31-Dec-97
# 3                      N             Y           NaN          30-Jun-97
# 4                      N             N           NaN          14-May-97
# ...                  ...           ...           ...                ...
# 899159                 0             N           NaN          30-Sep-97
# 899160                 Y             N           NaN          31-Oct-97
# 899161                 N             N           NaN          30-Sep-97
# 899162                 N             Y      8-Mar-00          31-Mar-97
# 899163                 N             N           NaN          31-May-97
#
#         amount_disbursed  gross_amount_outstanding  loan_status  \
# 0            $60,000.00                     $0.00         P I F
# 1            $40,000.00                     $0.00         P I F
# 2           $287,000.00                     $0.00         P I F
# 3            $35,000.00                     $0.00         P I F
# 4           $229,000.00                     $0.00         P I F
# ...                  ...                       ...          ...
# 899159       $70,000.00                     $0.00         P I F
# 899160       $85,000.00                     $0.00         P I F
# 899161      $300,000.00                     $0.00         P I F
# 899162       $75,000.00                     $0.00        CHGOFF
# 899163       $30,000.00                     $0.00         P I F
#
#        ghargedoff_amount gross_amount_approved guaranteed_sba
# 0                 $0.00            $60,000.00     $48,000.00
# 1                 $0.00            $40,000.00     $32,000.00
# 2                 $0.00           $287,000.00    $215,250.00
# 3                 $0.00            $35,000.00     $28,000.00
# 4                 $0.00           $229,000.00    $229,000.00
# ...                  ...                   ...            ...
# 899159            $0.00            $70,000.00     $56,000.00
# 899160            $0.00            $85,000.00     $42,500.00
# 899161            $0.00           $300,000.00    $225,000.00
# 899162       $46,383.00            $75,000.00     $60,000.00
# 899163            $0.00            $30,000.00     $24,000.00
#
# [899164 rows x 27 columns]

# %% [markdown]
# ### 3. Variable Clasification

# %% [markdown]
# Create a Data Dictionary

# %%
data_dictionary = GetDataDictionary(variables,new_columns)
display(data_dictionary)
# Out:
# The number of variables in the raw dataset is: 27
#                     Variable  Cluster  Disctint  \
# Id
# 21          amount_disbursed        4    118859
# 4               borrower_zip        4     33611
# 19              default_date        4      6449
# 20         disbursement_date        4      8473
# 1              borrower_name        4    779584
# 24         ghargedoff_amount        4     83165
# 25     gross_amount_approved        4     22128
# 2              borrower_city        4     32582
# 26            guaranteed_sba        4     38326
# 0                         id        4    899164
# 5                  bank_name        4      5803
# 8              approval_date        4      9859
# 15                 franchise        3      2768
# 7                       naic        2      1312
# 6                 bank_state        1        57
# 9       approval_fiscal_year        1        75
# 3             borrower_state        1        52
# 16                     urban        1         3
# 12             business_type        1         4
# 13              created_jobs        1       246
# 10              spected_term        1       412
# 22  gross_amount_outstanding        1        15
# 23               loan_status        1         3
# 18              low_doc_loan        1         9
# 14             retained_jobs        1       358
# 17          revolving_credit        1        19
# 11                 employees        1       599
#
#                                                Values           Type   Nulls  \
# Id
# 21  [$60,000.00 , $40,000.00 , $287,000.00 , $35,0...            str       0
# 4   [47711, 46526, 47401, 74012, 32801, 6062, 7083...    numpy.int64       0
# 19  [nan, 24-Jun-91, 18-Apr-02, 4-Oct-89, 26-Jun-1...          float  736465
# 20  [28-Feb-99, 31-May-97, 31-Dec-97, 30-Jun-97, 1...            str    2368
# 1   [ABC HOBBYCRAFT, LANDMARK BAR & GRILLE (THE), ...            str      14
# 24  [$0.00 , $208,959.00 , $14,084.00 , $44,374.00...            str       0
# 25  [$60,000.00 , $40,000.00 , $287,000.00 , $35,0...            str       0
# 2   [EVANSVILLE, NEW PARIS, BLOOMINGTON, BROKEN AR...            str      30
# 26  [$48,000.00 , $32,000.00 , $215,250.00 , $28,0...            str       0
# 0   [1000014003, 1000024006, 1000034009, 100004400...    numpy.int64       0
# 5   [FIFTH THIRD BANK, 1ST SOURCE BANK, GRANT COUN...            str    1559
# 8   [28-Feb-97, 2-Jun-80, 7-Feb-06, 11-Jun-80, 4-O...            str       0
# 15  [1, 0, 15100, 19755, 10656, 22470, 16267, 2142...    numpy.int64       0
# 7   [451120, 722410, 621210, 0, 332721, 811118, 72...    numpy.int64       0
# 6   [OH, IN, OK, FL, DE, SD, AL, CT, GA, OR, MN, R...            str    1566
# 9   [1997, 1980, 2006, 1998, 1999, 2000, 2001, 197...            int       0
# 3   [IN, OK, FL, CT, NJ, NC, IL, RI, TX, VA, TN, A...            str      14
# 16                                          [0, 1, 2]    numpy.int64       0
# 12                               [2.0, 1.0, 0.0, nan]  numpy.float64     136
# 13  [0, 7, 30, 5, 4, 1, 20, 10, 3, 8, 16, 15, 6, 1...    numpy.int64       0
# 10  [84, 60, 180, 240, 120, 45, 297, 162, 12, 300,...    numpy.int64       0
# 22  [$0.00 , $12,750.00 , $827,875.00 , $25,000.00...            str       0
# 23                               [P I F, CHGOFF, nan]            str    1997
# 18                      [Y, N, C, 1, nan, S, R, A, 0]            str    2582
# 14  [0, 7, 23, 4, 6, 1, 9, 20, 2, 5, 19, 8, 3, 10,...    numpy.int64       0
# 17  [N, 0, Y, T, nan, `, ,, 1, C, 3, 2, R, 7, A, 5...            str    4528
# 11  [4, 2, 7, 14, 19, 45, 1, 3, 24, 5, 16, 12, 6, ...    numpy.int64       0
#
#                                           Description
# Id
# 21                                   Amount disbursed
# 4                                   Borrower zip code
# 19                    loan default´s declaration date
# 20              the date upon which the Loan proceeds
# 1                                       Borrower Name
# 24  debt that a company believes it will no longer...
# 25  gross disbursements represent the amount of ch...
# 2                                       Borrower city
# 26                            SBA´s guaranteed amount
# 0                            Identifier - Primary key
# 5                                           Bank name
# 8                          Date SBA commitment issued
# 15                                     Franchise code
# 7              North American Industry classification
# 6                                          Bank state
# 9                           Fiscal year of commitment
# 3                                      Borrower state
# 16                                     Urban or Rural
# 12                                      Business Type
# 13                             Number of jobs created
# 10                            Loan termination months
# 22  the total of all remaining payments due under ...
# 23                                        Loan Status
# 18                                LowDoc Loan Program
# 14                            Number of jobs retained
# 17                           Revolving line of credit
# 11                       Number of business employees

# %%
variables.describe().T
# Out:
#                      count             mean              std              min  \
# id            899164.00000 4772612310.59431 2538175037.45304 1000014003.00000
# borrower_zip  899164.00000      53804.39124      31184.15915          0.00000
# naic          899164.00000     398660.95015     263318.31276          0.00000
# spected_term  899164.00000        110.77308         78.85731          0.00000
# employees     899164.00000         11.41135         74.10820          0.00000
# business_type 899028.00000          1.28040          0.45175          0.00000
# created_jobs  899164.00000          8.43038        236.68817          0.00000
# retained_jobs 899164.00000         10.79726        237.12060          0.00000
# franchise     899164.00000       2753.72593      12758.01914          0.00000
# urban         899164.00000          0.75775          0.64644          0.00000
#
#                            25%              50%              75%  \
# id            2589757508.50000 4361439006.00000 6904626504.75000
# borrower_zip       27587.00000      55410.00000      83704.00000
# naic              235210.00000     445310.00000     561730.00000
# spected_term          60.00000         84.00000        120.00000
# employees              2.00000          4.00000         10.00000
# business_type          1.00000          1.00000          2.00000
# created_jobs           0.00000          0.00000          1.00000
# retained_jobs          0.00000          1.00000          4.00000
# franchise              1.00000          1.00000          1.00000
# urban                  0.00000          1.00000          1.00000
#
#                            max
# id            9996003010.00000
# borrower_zip       99999.00000
# naic              928120.00000
# spected_term         569.00000
# employees           9999.00000
# business_type          2.00000
# created_jobs        8800.00000
# retained_jobs       9500.00000
# franchise          99999.00000
# urban                  2.00000

# %%
figure = plt.figure(figsize=(16, 8))
sns.heatmap(variables.T.isnull(), cmap="crest", annot=False)
# Out:
# <AxesSubplot: >

# %% [markdown]
# * The BorrowerName have nulls but the id not, then we need to delete the BorrowerName, is not usefull for the exercise. Is a duplicate data

# %% [markdown]
# ---
#
# ## III. Save Observations

# %%
# Save Data Dictionary to avoid recalculate
data_dictionary.to_pickle('./dta_00_data_dict.dd',compression='gzip',protocol=0)
# Save the Normalized Columns
variables.to_pickle('./dta_00_dataset.dd',compression='gzip',protocol=0)
